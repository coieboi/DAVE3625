# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('NAS.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2003-12-18  19.482599  19.596901  19.025499  19.139799  19.139799
# 1  2003-12-19  19.368299  19.425501  18.282801  18.454201  18.454201
# 2  2003-12-22  18.739901  18.739901  17.997101  18.054300  18.054300
# 3  2003-12-23  17.997101  17.997101  17.368700  17.425800  17.425800
# 4  2003-12-24        NaN        NaN        NaN        NaN        NaN
#
#       Volume
# 0  4978496.0
# 1  1410901.0
# 2   137047.0
# 3   229418.0
# 4        NaN

# %%
df = df[(df['Open'] >= 0)]
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2003-12-18  19.482599  19.596901  19.025499  19.139799  19.139799
# 1  2003-12-19  19.368299  19.425501  18.282801  18.454201  18.454201
# 2  2003-12-22  18.739901  18.739901  17.997101  18.054300  18.054300
# 3  2003-12-23  17.997101  17.997101  17.368700  17.425800  17.425800
# 7  2003-12-29  17.425800  17.425800  16.854500  17.254400  17.254400
#
#       Volume
# 0  4978496.0
# 1  1410901.0
# 2   137047.0
# 3   229418.0
# 7   196206.0

# %%
df['Date'] = pd.to_datetime(df.Date,format = '%Y-%m-%d')
df.index = df['Date']

plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')

# %%
df.iloc[:, 0]= pd.to_datetime(df.iloc[:, 0]) 
df.set_index('Date',inplace=True)
df.dropna(inplace=True)
df.info()

X = df.drop(['Close'], axis=1)
X.dropna(inplace=True)
y = df['Close']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4218 entries, 2003-12-18 to 2020-10-16
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       4218 non-null   float64
#  1   High       4218 non-null   float64
#  2   Low        4218 non-null   float64
#  3   Close      4218 non-null   float64
#  4   Adj Close  4218 non-null   float64
#  5   Volume     4218 non-null   float64
# dtypes: float64(6)
# memory usage: 230.7 KB

# %%
from sklearn.model_selection import train_test_split
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size=0.3)

lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', lr.coef_)

print("Residual sum of squares: %.2f" % np.mean((lr.predict(X_test) - y_test) ** 2))

print('Variance score: %.2f' % lr.score(X_test, y_test))
# Out:
# Coefficients:
#  [ 1.64448885e-14 -1.66334774e-14  4.81228941e-16  1.00000000e+00
#  -6.77626358e-21]
# Residual sum of squares: 0.00
# Variance score: 1.00

# %%
real = pd.read_csv('NAS.csv')
real = real[(real['Open'] >= 0)]
real['Date'] = pd.to_datetime(real.Date,format = '%Y-%m-%d')

# %%
y_test.sort_index(inplace=True)
y_train.sort_index(inplace=True)

real['Date'].sort_index(inplace=True)
real.index = real['Date']

plt.figure(figsize=(20,10))
plt.plot(real['Close'], 'r-', linewidth=1, label='Close Price')
plt.plot(y_train,linewidth=2, label='Predicted Close Price')
plt.legend(loc='upper center')
plt.title('Predicted Close Price of NAS')
plt.grid()

# %%
y_test.sort_index(inplace=True)
y_train.sort_index(inplace=True)

real['Date'].sort_index(inplace=True)


plt.figure(figsize=(20,10))
plt.plot(real['Close'], 'b', linewidth=5, label='Close Price')
plt.plot(real['Date'],lr.predict(X), 'r-',linewidth=1, label='Predicted Close Price')
plt.legend(loc='upper center')
plt.title('Predicted Close Price of NAS')
plt.grid()

# %%
date = y_test[::-1]
get_date_value = date[x]

# Enter date in x-string
x = '2015-05-07'
get_date_value = date[x]
#Gives get_data_value of date x
get_date_value
# Out:
# Date
# 2015-05-07    178.942993
# Name: Close, dtype: float64

# %%
Pred = lr.predict(X)
dato = real['Date']
df2 = pd.DataFrame({"Dato":dato, 
                    "Prediction":Pred})
del df2['Dato']

# %%
Dato.sort_index(inplace=True)

Dato = df2[::-1]
get_date_pred_value = Dato[:t]

Dato[t:t]
# Out:
# Empty DataFrame
# Columns: [Prediction]
# Index: []

# %%
def Pred_Dato_Value(t):
    Dato = df2[::-1]
    print (Dato[t:t])
    return;

# %%
# Input: Date -> Output: Prediction
Pred_Dato_Value('2011-11-15')
# Out:
#             Prediction
# Date
# 2011-11-15   40.850601
